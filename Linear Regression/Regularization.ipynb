# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.replace('?', np.nan, inplace = True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
si = SimpleImputer()

df.iloc[:,[1,11]] = si.fit_transform(df.iloc[:,[1,11]])
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#      horsepower  city-mpg  highway-mpg  price
# 0         111.0        21           27  13495
# 1         111.0        21           27  16500
# 2         154.0        19           26  16500
# 3         102.0        24           30  13950
# 4         115.0        18           22  17450
# ..          ...       ...          ...    ...
# 200       114.0        23           28  16845
# 201       160.0        19           25  19045
# 202       134.0        18           23  21485
# 203       106.0        26           27  22470
# 204       114.0        19           25  22625
#
# [205 rows x 15 columns]

# %%
cat_cols = df.select_dtypes(object).columns
cat_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
oe = OrdinalEncoder()

df[cat_cols] = oe.fit_transform(df[cat_cols])
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0   0.0        1.0         0.0           2.0
# 1            3              122.0   0.0        1.0         0.0           2.0
# 2            1              122.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                0.0   64.1    48.8          0.0          130       111.0
# 1                0.0   64.1    48.8          0.0          130       111.0
# 2                0.0   65.5    52.4          5.0          152       154.0
# 3                0.0   66.2    54.3          3.0          109       102.0
# 4                0.0   66.4    54.3          3.0          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 200              0.0   68.9    55.5          3.0          141       114.0
# 201              0.0   68.8    55.5          3.0          141       160.0
# 202              0.0   68.9    55.5          5.0          173       134.0
# 203              0.0   68.9    55.5          3.0          145       106.0
# 204              0.0   68.9    55.5          3.0          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size = 0.3, random_state = 1)

# %%
lr = LinearRegression()
lr.fit(xtrain, ytrain)
ypred = lr.predict(xtest)

print(f"Train Accuracy is {lr.score(xtrain, ytrain)} \nTest Accuracy is {lr.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.8539412613914049
# Test Accuracy is 0.7440263258545711

# %%
lr.coef_
# Out:
# array([ 8.10627829e+01, -4.98250716e+00, -1.93628369e+02, -3.96939528e+02,
#        -1.59308387e+02,  2.03453658e+03,  1.61641371e+04,  8.12358117e+02,
#         2.86594382e+02,  3.04469374e+02,  9.72915986e+01, -1.24843308e+01,
#         2.37997595e+02, -3.56739524e+02])

# %% [markdown]
# # Lasso Regression

# %%
l1 = Lasso(alpha = 1)
l1.fit(xtrain, ytrain)

print(f"Train Accuracy is {l1.score(xtrain, ytrain)} \nTest Accuracy is {l1.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.8539398244720607
# Test Accuracy is 0.7442680796367558

# %%
l1.coef_
# Out:
# array([ 8.10099235e+01, -4.98244205e+00, -1.93459787e+02, -3.89872260e+02,
#        -1.60587747e+02,  2.03168757e+03,  1.60855755e+04,  8.10235442e+02,
#         2.87249208e+02,  3.04384733e+02,  9.73692186e+01, -1.23519330e+01,
#         2.36917278e+02, -3.55445582e+02])

# %% [markdown]
# # Hyperparameter Tuning

# %%
for i in range(100, 200):
    l1 = Lasso(alpha = i)
    l1.fit(xtrain, ytrain)
    
    print(f"{i} {l1.score(xtrain, ytrain)} {l1.score(xtest, ytest)}")
# Out:
# 100 0.8399550254990269 0.7644150726044205
# 101 0.8396765068564949 0.7645910215883885
# 102 0.8393951129870751 0.7647659882285331
# 103 0.8391110603761689 0.7649401532453524
# 104 0.8388242397338377 0.7651134250740712
# 105 0.8385345349342124 0.7652857085507111
# 106 0.8382421762634075 0.7654571927954633
# 107 0.8379470482259248 0.7656277826674934
# 108 0.837649029554768 0.7657973803678717
# 109 0.8373483618984794 0.7659661812330151
# 110 0.8370449238236125 0.7661340868339707
# 111 0.836738589066682 0.7663009968898453
# 112 0.8364296146136767 0.7664671159710184
# 113 0.8361177485059503 0.7666322443886752
# 114 0.8358032437723879 0.7667965815573106
# 115 0.8354858300186775 0.7669599153505952
# 116 0.8351657814298425 0.7671224598759211
# 117 0.8348428153561449 0.7672839955065129
# 118 0.8345172182613106 0.7674447438786604
# 119 0.8341887040017569 0.7676044846703385
# 120 0.8338575681406851 0.7677634444292694
# 121 0.833523511083555 0.7679213945163487
# 122 0.8331868353897822 0.7680785647942531
# 123 0.832847230094472 0.7682347200504736
# 124 0.8325050132398909 0.7683900998288432
# 125 0.8321598658436502 0.7685444648832082
# 126 0.8318121110259297 0.768698056513397
# 127 0.8314614189430389 0.7688506294034285
# 128 0.8311081249368946 0.769002431922685
# 129 0.830751888451875 0.769153212850912
# 130 0.8303930623265704 0.7693032313819589
# 131 0.8300312975699928 0.7694522320540774
# 132 0.8296669407592039 0.7696004674524939
# 133 0.8292996341498702 0.769747677808556
# 134 0.8289295541958841 0.7698939914994921
# 135 0.8285568932056011 0.7700395463298332
# 136 0.8281812733640991 0.7701840710565171
# 137 0.8278028808219657 0.7703276995643579
# 138 0.8274217158128865 0.7704704320196867
# 139 0.8270379859714487 0.7706124150583675
# 140 0.8266512830609836 0.7707533598387856
# 141 0.826261808598699 0.7708934091782005
# 142 0.8258695642921345 0.7710325642629072
# 143 0.8254747695776959 0.771170977905446
# 144 0.8250769887543986 0.771308346110496
# 145 0.8246764380041747 0.7714448199404746
# 146 0.8242731178406684 0.7715803997327543
# 147 0.8238670288304109 0.7717150858568781
# 148 0.8234581715970459 0.7718488787170119
# 149 0.8230465467312356 0.7719817786899407
# 150 0.8226321544747064 0.7721137859105283
# 151 0.8222152484003333 0.7722450724036388
# 152 0.8217950727308212 0.7723751253161624
# 153 0.8213723851142343 0.7725044586836464
# 154 0.8209469343924907 0.7726329020349421
# 155 0.8205187217270197 0.7727604560955132
# 156 0.8200877483821903 0.772887121651628
# 157 0.8196540157330161 0.7730128995547132
# 158 0.8192175252733815 0.7731377907259909
# 159 0.818777990633521 0.7732616053993674
# 160 0.8183359901422184 0.7733847271140009
# 161 0.8178909393776681 0.77350676922057
# 162 0.8174434417548807 0.7736281295767538
# 163 0.8169928859423529 0.7737484060023355
# 164 0.8165399028019771 0.7738680120905651
# 165 0.816083806600358 0.773986499345273
# 166 0.8156249548025751 0.7741041017816234
# 167 0.8151633624590349 0.7742208290560416
# 168 0.8146990388110401 0.7743366869701345
# 169 0.8142320961689136 0.7744517476841888
# 170 0.813762160321102 0.7745657699036098
# 171 0.8132895748074116 0.7746789749631497
# 172 0.8128143852048073 0.774791391378468
# 173 0.8123359123999286 0.774902585026915
# 174 0.8118550145392149 0.7750131037205219
# 175 0.8113715449305817 0.7751228488022202
# 176 0.8108848477369702 0.7752313488411899
# 177 0.810398027912919 0.7753376305711425
# 178 0.8099158018643546 0.7754478182455511
# 179 0.8094293509613448 0.7755604872007467
# 180 0.8089522112088927 0.775663351223856
# 181 0.8084745716650822 0.7757692197002906
# 182 0.8079937860511276 0.7758755691448505
# 183 0.8075094384915956 0.7759820493662806
# 184 0.8070226130969378 0.7760874938213442
# 185 0.806533873373297 0.7761911484092056
# 186 0.8060424845967606 0.7762938974357994
# 187 0.8055484467673291 0.7763957409011255
# 188 0.805051759885002 0.7764966788051844
# 189 0.8045524239497795 0.7765967111479755
# 190 0.8040504389616616 0.776695837929499
# 191 0.8035458049206485 0.7767940591497547
# 192 0.80303852182674 0.7768913748087427
# 193 0.8025280114262019 0.7769885911089183
# 194 0.8020154278048237 0.7770841030702453
# 195 0.8015001951364911 0.7771787094763878
# 196 0.8009823129490374 0.7772724086649718
# 197 0.8004617812977742 0.7773651852678698
# 198 0.7999386005905046 0.7774570563051009
# 199 0.7994127708272276 0.7775480217766626

# %%
l1 = Lasso(alpha = 170)
l1.fit(xtrain, ytrain)

print(f"Train Accuracy is {l1.score(xtrain, ytrain)} \nTest Accuracy is {l1.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.813762160321102
# Test Accuracy is 0.7745657699036098

# %% [markdown]
# # Ridge Regression

# %%
l2 = Ridge()
l2.fit(xtrain, ytrain)

print(f"Train Accuracy is {l2.score(xtrain, ytrain)} \nTest Accuracy is {l2.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.8482674089811111
# Test Accuracy is 0.7597037544007509

# %%
for i in range(1,50):
    l2 = Ridge(alpha = i)
    l2.fit(xtrain, ytrain)
    
    print(f"{i} {l2.score(xtrain, ytrain)} {l2.score(xtest, ytest)}")
# Out:
# 1 0.8482674089811111 0.7597037544007509
# 2 0.8415619363937635 0.7655470158349814
# 3 0.8363951508249314 0.7685522366994493
# 4 0.8324610677838388 0.7703895039721603
# 5 0.8293863299288738 0.7716361765232881
# 6 0.8269124234824408 0.7725405637365281
# 7 0.8248693933233863 0.7732264194061074
# 8 0.8231441159269753 0.7737624277305333
# 9 0.82165935802416 0.77418998914559
# 10 0.8203609531530248 0.7745357446711172
# 11 0.8192099407731408 0.7748177686083774
# 12 0.8181776487192544 0.7750488663114246
# 13 0.8172425389038229 0.7752384410630868
# 14 0.8163881323933204 0.7753936067841302
# 15 0.8156016116243241 0.7755198811711728
# 16 0.8148728578870452 0.7756216343440712
# 17 0.814193775120706 0.775702389170018
# 18 0.8135578061085905 0.7757650283597382
# 19 0.812959580531318 0.7758119410917473
# 20 0.8123946550311475 0.7758451292906464
# 21 0.8118593185518815 0.7758662862953722
# 22 0.8113504446953665 0.7758768561943044
# 23 0.8108653784189215 0.7758780793379442
# 24 0.8104018481402175 0.7758710277800905
# 25 0.8099578968650145 0.7758566332527805
# 26 0.8095318277154503 0.7758357095185242
# 27 0.8091221604720196 0.7758089704268601
# 28 0.8087275966197641 0.7757770446457071
# 29 0.8083469910198295 0.7757404877876712
# 30 0.8079793287859489 0.7756997924729909
# 31 0.8076237062821401 0.7756553967416565
# 32 0.8072793154077205 0.7756076911325869
# 33 0.8069454305227693 0.7755570246773846
# 34 0.8066213975084483 0.7755037100033907
# 35 0.8063066245641622 0.7754480277005839
# 36 0.80600057442611 0.7753902300760602
# 37 0.8057027577555931 0.7753305443959513
# 38 0.8054127274951415 0.7752691756959362
# 39 0.8051300740294461 0.7752063092267905
# 40 0.8048544210187941 0.7751421125896794
# 41 0.8045854217970483 0.7750767376065446
# 42 0.8043227562456459 0.7750103219633416
# 43 0.8040661280706745 0.7749429906577688
# 44 0.8038152624226409 0.7748748572780986
# 45 0.8035699038087363 0.7748060251356028
# 46 0.8033298142556796 0.7747365882696797
# 47 0.8030947716880068 0.7746666323419393
# 48 0.8028645684922322 0.7745962354331799
# 49 0.8026390102419068 0.7745254687551882

# %%
l2 = Ridge(alpha = 10)
l2.fit(xtrain, ytrain)

print(f"Train Accuracy is {l2.score(xtrain, ytrain)} \nTest Accuracy is {l2.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.8203609531530248
# Test Accuracy is 0.7745357446711172

# %% [markdown]
# # Elastic Net

# %%
en = ElasticNet()
en.fit(xtrain, ytrain)

print(f"Train Accuracy is {en.score(xtrain, ytrain)} \nTest Accuracy is {en.score(xtest, ytest)}")
# Out:
# Train Accuracy is 0.7969654339953139
# Test Accuracy is 0.7722146104160097
